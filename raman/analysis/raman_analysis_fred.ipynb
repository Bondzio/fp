# %%
# %load ../../style.py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import colorConverter
from matplotlib import rcParams
import seaborn as sns
from scipy.optimize import curve_fit

sns.set(style='ticks', palette='Set2') 
sns.despine()

fontsize_labels = 26    # size used in latex document
rcParams['text.latex.preamble'] = [r'\usepackage[cmbright]{sfmath}']
rcParams['font.family']= 'sans-serif'
rcParams['font.sans-serif']= 'cmbright'
rcParams['font.weight'] = "light"

rcParams['text.usetex'] = True

rcParams['figure.autolayout'] = True
rcParams['font.size'] = fontsize_labels
rcParams['axes.labelsize'] = fontsize_labels
rcParams['xtick.labelsize'] = fontsize_labels
rcParams['ytick.labelsize'] = fontsize_labels
rcParams['legend.fontsize'] = fontsize_labels
rcParams['axes.titlesize'] = fontsize_labels
xfactor = 2
rcParams['figure.figsize'] = (xfactor*6.2, xfactor*3.83)

# %%
import re
from scipy.constants import c
from scipy.constants import h
from scipy.constants import c,h,eV
hceV = h * c  /eV
find_number = lambda string: re.search("-?\\d+",string).group(0)

from smooth import savitzky_golay

# %%
lamb = np.load("npy/mono_white_full_01_lamb.npy")/10
count = np.load("npy/mono_white_full_01_count.npy")

fig, ax = plt.subplots(1,1)
ax.plot(lamb,count, ".", alpha = 0.3)
ax.plot(lamb, savitzky_golay(count,61,3))

ax.set_ylim(0,25000)
ax.set_xlim(400,700)
ax.set_xlabel("wavelength $\lambda$ in nm")
ax.set_ylabel("counts")
ax.set_title("Monochromator with white light: Full spectrum")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:1596: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
filename = "mono_hg"
lamb = np.load("npy/"+filename+"_lamb.npy")/10
count = np.load("npy/"+filename+"_count.npy")

fig, ax = plt.subplots(1,1)
ax.plot(lamb,count, ",", alpha = 0.8)
ax.plot(lamb,count, "-", alpha = 0.3, color = "green")
#ax.plot(lamb, savitzky_golay(count,15,3))
#ax.fill_between(lamb,count - np.sqrt(count),count + np.sqrt(count))
#ax.set_ylim(0,25000)
ax.set_yscale("log")
ax.set_xlim(400,600)
ax.set_xlabel("wavelength $\lambda$ in $nm$")
ax.set_ylabel("counts")
ax.set_title("Monochromator with white light: Full spectrum")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3.4/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
files = ["mono_slit_100", "mono_slit_150","mono_slit_200","mono_slit_25", \
      "mono_slit_25_02","mono_slit_40", "mono_slit_50","mono_slit_75"]
fig, ax = plt.subplots(1,1)
colors = sns.diverging_palette(220, 20, n = len(files))
for n, filename in enumerate(files): 
    lamb = np.load("npy/"+filename+"_lamb.npy")/10
    count = np.load("npy/"+filename+"_count.npy")
    
    ax.plot(lamb,count, "-", alpha = 0.8,label = "$"+find_number(filename)+"$", color= colors[n])
    ax.scatter(lamb,count, alpha = 0.8, color= colors[n],s = 60)
ax.legend(title="width of gap/ $\mu m$", loc =2)
ax.set_ylim(0,500000)
ax.set_xlim(404,405)
ax.set_xlabel("wavelength $\lambda$ in $nm$")
ax.set_ylabel("counts")
ax.set_title("Monochromator with white light: Full spectrum")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3.4/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
file_list = ["mono_white_full_01", "mono_white_pol0"]

# %%
filename = "mono_cs2"
lamb = np.load("npy/"+filename+"_lamb.npy")/10
count = np.load("npy/"+filename+"_count.npy")
E  = lamb
fig, ax = plt.subplots(1,1)
ax.plot(E,count, "-", alpha = 0.8)
#ax.plot(lamb, savitzky_golay(count,21,5))
#ax.fill_between(lamb,count - np.sqrt(count),count + np.sqrt(count))
#ax.set_ylim(0,600000)
ax.set_xlim(400,600)
ax.set_xlabel("wavelength in $nm$")
ax.set_ylabel("counts")
ax.set_title("Monochromator with white $CS_2$: Full spectrum")
ax.set_yscale("log")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3.4/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
filename = "mono_cs2_04"
lamb = np.load("npy/"+filename+"_lamb.npy")/10
count = np.load("npy/"+filename+"_count.npy")

fig, ax = plt.subplots(1,1)
ax.plot(lamb,count, ",", alpha = 0.8)
ax.plot(lamb,count, "-", alpha = 0.3, color = "green")
#ax.plot(lamb, savitzky_golay(count,15,3))
#ax.fill_between(lamb,count - np.sqrt(count),count + np.sqrt(count))
ax.set_ylim(0,2e6)
#ax.set_yscale("log")
ax.set_xlim(500,580)
ax.set_xlabel("wavelength $\lambda$ in $nm$")
ax.set_ylabel("counts")
ax.set_title("Monochromator with white light: Full spectrum")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3.4/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
filename = "mono_chcl3_01"
lamb = np.load("npy/"+filename+"_lamb.npy")/10
count = np.load("npy/"+filename+"_count.npy")

fig, ax = plt.subplots(1,1)
ax.plot(lamb,count, ",", alpha = 0.8)
ax.plot(lamb,count, "-", alpha = 0.3, color = "green")
#ax.plot(lamb, savitzky_golay(count,15,3))
#ax.fill_between(lamb,count - np.sqrt(count),count + np.sqrt(count))
ax.set_ylim(30000,55000)
#ax.set_yscale("log")
ax.set_xlim(510,550)
ax.set_xlabel("wavelength $\lambda$ in $nm$")
ax.set_ylabel("counts")
ax.set_title("Monochromator with white light: Full spectrum")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3.4/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
filename = "ccd_s_130"
lamb = np.load("npy/"+filename+"_lamb.npy")
count = np.load("npy/"+filename+"_count.npy")

filename = "ccd_bg_30_10"
count_bg = np.load("npy/"+filename+"_count.npy")


fig, ax = plt.subplots(1,1)
ax.plot(lamb,count_bg/10, "-", alpha = 0.6)
#ax.plot(lamb,count - count_bg, "-", alpha = 0.6)
ax.plot(lamb, savitzky_golay(count-count_bg, 25, 5))

#ax.fill_between(lamb,count - np.sqrt(count),count + np.sqrt(count))
ax.set_ylim(-1000,2000)
#ax.set_yscale("log")
ax.set_xlim(420,620)
ax.set_xlabel("wavelength $\lambda$ in nm")
ax.set_ylabel("counts")
ax.set_title("CCD, sulfur")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:1596: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
filename = "ccd_et_org"
lamb = np.load("npy/"+filename+"_lamb.npy")
count = np.load("npy/"+filename+"_count.npy")

filename = "ccd_et_40"
lamb2 = np.load("npy/"+filename+"_lamb.npy")
count2 = np.load("npy/"+filename+"_count.npy")

filename = "ccd_bg_30_10"
count_bg = np.load("npy/"+filename+"_count.npy")


fig, ax = plt.subplots(1,1)
#ax.plot(lamb, count_bg, "-", alpha = 0.9)
ax.plot(lamb,count - count_bg, "-", alpha = 0.6)
#ax.plot(lamb, savitzky_golay(count-count_bg, 25, 5))
ax.plot(lamb,count2 - count_bg, "-", alpha = 0.6)
#ax.plot(lamb, savitzky_golay(count2-count_bg, 25, 5))
ax.set_ylim(-3000,20000)
#ax.set_yscale("log")
ax.set_xlim(420,620)
ax.set_xlabel("wavelength $\lambda$ in $nm$")
ax.set_ylabel("counts")
ax.set_title("CCD, ethanol")
ax.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-126-7c782ef1958a> in <module>()
#       1 filename = "ccd_et_org"
# ----> 2 lamb = np.load("npy/"+filename+"_lamb.npy")
#       3 count = np.load("npy/"+filename+"_count.npy")
#       4
#       5 filename = "ccd_et_40"
#
# /usr/lib/python3/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode)
#     368     own_fid = False
#     369     if isinstance(file, basestring):
# --> 370         fid = open(file, "rb")
#     371         own_fid = True
#     372     elif isinstance(file, gzip.GzipFile):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'npy/ccd_et_org_lamb.npy'

# %%
filename = "ccd_ccl4_notch_l2"
lamb = np.load("npy/"+filename+"_lamb.npy")
count = np.load("npy/"+filename+"_count.npy")

filename = "ccd_ccl4_l2"
lamb2 = np.load("npy/"+filename+"_lamb.npy")
count2 = np.load("npy/"+filename+"_count.npy")

filename = "ccd_bg_30_10"
count_bg = np.load("npy/"+filename+"_count.npy")

   
fig, ax = plt.subplots(1,1)
ax.plot(lamb,count, "-", alpha = 0.8)
ax.plot(lamb2,count2, "-", alpha = 0.8)
#ax.plot(lamb,count_bg, "-", alpha = 0.3)
#ax.plot(lamb,count - count_bg, "-", alp8a = 0.6)
#ax.plot(lamb, savitzky_golay(count-count8bg, 25, 5))
#ax.fill_between(lamb,count - np.sqrt(count),count + np.sqrt(count))
ax.set_ylim(-2000,100000)
#ax.set_yscale("log")
ax.set_xlim(480,580)
ax.set_xlabel("wavelength $\lambda$ in $nm$")
ax.set_ylabel("counts")
ax.set_title("CCD, CCl$_4$")
ax.grid(True)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:1596: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# # The laser is polarized horizontally!!!
